# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as req

# %%
import pandas as pd

# %%
df =pd.read_csv(r"C:\Users\jelsa\OneDrive\Documentos\ironhack-proj\apis\US_violent_crime.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
#conda install -c conda-forge selenium

# %%
#%pip install webdriver-manager

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
from selenium.webdriver.common.by import By 

import time

import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_violent_crime_rate'

# %%
from selenium import webdriver

# %%
PATH = ChromeDriverManager().install()     

driver=webdriver.Chrome(PATH)

# %%
driver.get(url)

# %%
# vamos a meterle una imagen de eeuu para que sea más iteractivo

# %%
US_crime_map= [e.get_attribute('src') for e in driver.find_elements(By.TAG_NAME, 'img')]
US_crime_map[3]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/Violent_Crime_Rate_by_U.S._state.svg/550px-Violent_Crime_Rate_by_U.S._state.svg.png'

# %%
# vamos a meter más columnas.

# %%
crime_rate = driver.find_elements(By.TAG_NAME, 'b')
crime_rate[2].text
# Out:
# '999.8'

# %%
new_crime_rate = []

for i in crime_rate:
    new_crime_rate.append(i.text.strip())
print(new_crime_rate)
# Out:
# ['list of U.S. states and territories by violent crime rate', '7,127', '999.8', '6,126', '837.8', '16,393', '778.3', '46,328', '672.7', '20,363', '671.9', '35,980', '654.8', '29,704', '639.4', '33,385', '542.7', '27,691', '530.7', '4,476', '501.4', '47,641', '478.0', '5,077', '469.8', '14,445', '460.3', '18,255', '458.6', '22,322', '453.6', '131,084', '446.5', '174,026', '442.0', '4,262', '431.9', '53,612', '425.9', '12,835', '425.0', '24,570', '423.1', '44,451', '419.3', '42,850', '400.1', '24,215', '399.9', '49,793', '389.5', '83,368', '383.6', '70,339', '363.8', '24,161', '357.7', '6,352', '355.9', '6,473', '334.1', '2,518', '329.0', '18,861', '323.4', '36,104', '308.8', '21,288', '308.8', '9,601', '303.5', '22,596', '293.7', '12,380', '291.9', '8,638', '291.2', '15,698', '277.5', '8,471', '260.7', '11,600', '259.1', '3,576', '254.2', '4,432', '242.6', '1,364', '234.2', '2,440', '230.8', '17,925', '208.0', '17,353', '195.4', '6,459', '181.6', '1,081', '173.4', '5,196', '164.5', '2
# ...

# %%
def extract_numbers(lst):                                          # limpiar la lista que nos ha dado
    return [x for x in lst if x.replace('.','',1).isdigit()]

print(extract_numbers(['list of U.S. states and territories by violent crime rate', '7,127', '999.8', '6,126', '837.8', '16,393', '778.3', '46,328', '672.7', '20,363', '671.9', '35,980', '654.8', '29,704', '639.4', '33,385', '542.7', '27,691', '530.7', '4,476', '501.4', '47,641', '478.0', '5,077', '469.8', '14,445', '460.3', '18,255', '458.6', '22,322', '453.6', '131,084', '446.5', '174,026', '442.0', '4,262', '431.9', '53,612', '425.9', '12,835', '425.0', '24,570', '423.1', '44,451', '419.3', '42,850', '400.1', '24,215', '399.9', '49,793', '389.5', '83,368', '383.6', '70,339', '363.8', '24,161', '357.7', '6,352', '355.9', '6,473', '334.1', '2,518', '329.0', '18,861', '323.4', '36,104', '308.8', '21,288', '308.8', '9,601', '303.5', '22,596', '293.7', '12,380', '291.9', '8,638', '291.2', '15,698', '277.5', '8,471', '260.7', '11,600', '259.1', '3,576', '254.2', '4,432', '242.6', '1,364', '234.2', '2,440', '230.8', '17,925', '208.0', '17,353', '195.4', '6,459', '181.6', '1,081', '173.4', '5,196', '164.5', '2,000', '146.4', '1,466', '108.6', '1,313,105', 'a', 'b', 'c', 'a', 'b', '']))
# Out:
# ['999.8', '837.8', '778.3', '672.7', '671.9', '654.8', '639.4', '542.7', '530.7', '501.4', '478.0', '469.8', '460.3', '458.6', '453.6', '446.5', '442.0', '431.9', '425.9', '425.0', '423.1', '419.3', '400.1', '399.9', '389.5', '383.6', '363.8', '357.7', '355.9', '334.1', '329.0', '323.4', '308.8', '308.8', '303.5', '293.7', '291.9', '291.2', '277.5', '260.7', '259.1', '254.2', '242.6', '234.2', '230.8', '208.0', '195.4', '181.6', '173.4', '164.5', '146.4', '108.6']

# %%
df['crime_rate'] = ['999.8', '837.8', '778.3', '672.7', '671.9', '654.8', '639.4', '542.7', '530.7', '501.4', '478.0', '469.8', '460.3', '458.6', '453.6', '446.5', '442.0', '431.9', '425.9', '425.0', '423.1', '419.3', '400.1', '399.9', '389.5', '383.6', '363.8', '357.7', '355.9', '334.1', '329.0', '323.4', '308.8', '308.8', '303.5', '293.7', '291.9', '291.2', '277.5', '260.7', '259.1', '254.2', '242.6', '234.2', '230.8', '208.0', '195.4', '181.6', '173.4', '164.5',]

# %%
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape crime_rate
# 0     Alabama    13.2      236        58  21.2      999.8
# 1      Alaska    10.0      263        48  44.5      837.8
# 2     Arizona     8.1      294        80  31.0      778.3
# 3    Arkansas     8.8      190        50  19.5      672.7
# 4  California     9.0      276        91  40.6      671.9

# %%
df["crime_rate"] = 0    # le meto 0 porque quiero ordenar los datos de crime_rate por cada estado más abajo

# %%
df.at[0, "crime_rate"] = 453.6
df.at[1, "crime_rate"] = 837.8
df.at[2, "crime_rate"] = 654.8
df.at[3, "crime_rate"] = 671.9
df.at[4, "crime_rate"] = 442.0
df.at[5, "crime_rate"] = 423.1
df.at[6, "crime_rate"] = 181.6
df.at[7, "crime_rate"] = 431.9
df.at[8, "crime_rate"] = 383.6
df.at[9, "crime_rate"] = 400.1
df.at[10, "crime_rate"] = 254.2
df.at[11, "crime_rate"] = 242.6
df.at[12, "crime_rate"] = 425.9
df.at[13, "crime_rate"] = 357.7
df.at[14, "crime_rate"] = 303.5
df.at[15, "crime_rate"] = 425.0
df.at[16, "crime_rate"] = 259.1
df.at[17, "crime_rate"] = 639.4
df.at[18, "crime_rate"] = 108.6
df.at[19, "crime_rate"] = 399.9
df.at[20, "crime_rate"] = 308.8
df.at[21, "crime_rate"] = 478.0
df.at[22, "crime_rate"] = 277.5
df.at[23, "crime_rate"] = 291.2
df.at[24, "crime_rate"] = 542.7
df.at[25, "crime_rate"] = 469.8
df.at[26, "crime_rate"] = 334.1
df.at[27, "crime_rate"] = 460.3
df.at[28, "crime_rate"] = 146.4
df.at[29, "crime_rate"] = 195.4
df.at[30, "crime_rate"] = 778.3
df.at[31, "crime_rate"] = 363.8
df.at[32, "crime_rate"] = 419.3
df.at[33, "crime_rate"] = 329.0
df.at[34, "crime_rate"] = 308.8
df.at[35, "crime_rate"] = 458.6
df.at[36, "crime_rate"] = 291.9
df.at[37, "crime_rate"] = 389.5
df.at[38, "crime_rate"] = 230.8
df.at[39, "crime_rate"] = 530.7
df.at[40, "crime_rate"] = 501.4
df.at[41, "crime_rate"] = 672.7
df.at[42, "crime_rate"] = 446.5
df.at[43, "crime_rate"] = 260.7
df.at[44, "crime_rate"] = 173.4
df.at[45, "crime_rate"] = 208.0
df.at[46, "crime_rate"] = 293.7
df.at[47, "crime_rate"] = 355.9
df.at[48, "crime_rate"] = 323.4
df.at[49, "crime_rate"] = 234.2

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
df.head(50)
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
# En vez de usar selenium voy a usar el metodo beautifulsoup

# %%
#%pip install beautifulsoup4

# %%
import requests as req

from bs4 import BeautifulSoup as bs

# %%
url = 'https://fred.stlouisfed.org/release/tables?eid=259515&rid=249'  # Tomo estos datos para insertar desde esta web los ingresos por familia de cada estado.

# %%
html=req.get(url).content
html[:100]
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  '

# %%
soup=bs(html, 'html.parser')

# %%
family_income= soup.find_all('td', class_="fred-rls-elm-vl-td")
family_income
# Out:
# [<td class="fred-rls-elm-vl-td">
#                70,784
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                71,186
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                          71,186
#                    </td>,
#  <td class="fred-rls-elm-vl-td">
#                56,929
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                57,243
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                          57,243
#                    </td>,
#  <td class="fred-rls-elm-vl-td">
#                81,133
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                78,236
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                          78,236
#                    </td>,
#  <td class="fred-rls-elm-vl-td">
#                70,821
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                70,220
#            </td>,
#  <td class="fred-rls-elm-vl-td">
#                          70,220
# ...

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
family_incomes = []

for i in family_income:
    family_incomes.append(i.text)
print(family_incomes)
# Out:
# ['\n              70,784\n          ', '\n              71,186\n          ', '\n                        71,186\n                  ', '\n              56,929\n          ', '\n              57,243\n          ', '\n                        57,243\n                  ', '\n              81,133\n          ', '\n              78,236\n          ', '\n                        78,236\n                  ', '\n              70,821\n          ', '\n              70,220\n          ', '\n                        70,220\n                  ', '\n              50,784\n          ', '\n              53,148\n          ', '\n                        53,148\n                  ', '\n              81,575\n          ', '\n              81,278\n          ', '\n                        81,278\n                  ', '\n              84,954\n          ', '\n              87,689\n          ', '\n                        87,689\n                  ', '\n              80,958\n          ', '\n              83,141\n          
# ...

# %%
family_incomes_clean = [e.replace('\n              ', '') for e in family_incomes]
family_incomes_clean[:5]
# Out:
# ['70,784\n          ',
#  '71,186\n          ',
#  '          71,186    ',
#  '56,929\n          ',
#  '57,243\n          ']

# %%
family_incomes_clean2 = [e.strip().replace(',', '') for e in family_incomes_clean]
family_incomes_clean2 = family_incomes_clean2[3:]

family_incomes_clean2[0::3]
# Out:
# ['56929',
#  '81133',
#  '70821',
#  '50784',
#  '81575',
#  '84954',
#  '80958',
#  '68687',
#  '90640',
#  '59734',
#  '61497',
#  '82199',
#  '76918',
#  '79253',
#  '70190',
#  '72429',
#  '75979',
#  '55629',
#  '57206',
#  '71139',
#  '97332',
#  '86566',
#  '64488',
#  '80441',
#  '46637',
#  '63594',
#  '64999',
#  '78109',
#  '64340',
#  '88841',
#  '88559',
#  '53463',
#  '72920',
#  '62891',
#  '68882',
#  '62689',
#  '60096',
#  '81855',
#  '72627',
#  '74982',
#  '62542',
#  '73893',
#  '62166',
#  '67404',
#  '87649',
#  '76079',
#  '80268',
#  '87648',
#  '46836',
#  '69943',
#  '71052']

# %%
df['family_incomes_clean2']=['56929',
 '81133',
 '70821',
 '50784',
 '81575',
 '84954',
 '80958',
 '68687',
 '59734',
 '61497',
 '82199',
 '76918',
 '79253',
 '70190',
 '72429',
 '75979',
 '55629',
 '57206',
 '71139',
 '97332',
 '86566',
 '64488',
 '80441',
 '46637',
 '63594',
 '64999',
 '78109',
 '64340',
 '88841',
 '88559',
 '53463',
 '72920',
 '62891',
 '68882',
 '62689',
 '60096',
 '81855',
 '72627',
 '74982',
 '62542',
 '73893',
 '62166',
 '67404',
 '87649',
 '76079',
 '80268',
 '87648',
 '46836',
 '69943',
 '71052']

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate  \
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
df = df.drop(["family_inc(dollars"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2228\2582642445.py in <module>
# ----> 1 df = df.drop(["family_inc(dollars"], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate  \
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
# renombro la columna de income a Family_income(dollars)

# %%
df=df.rename(columns={'family_incomes_clean2': 'family_incomes(dollars)'})

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate  \
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
data =pd.read_csv(r"C:\Users\jelsa\OneDrive\Documentos\ironhack-proj\apis\data.csv")

# %%
url='https://worldpopulationreview.com/state-rankings/alcohol-consumption-by-state'

# %%
data
# Out:
#     fips                 state    densityMi   pop2023   pop2022   pop2020  \
# 0      1               Alabama    100.65438   5097641   5073187   5024279
# 1      2                Alaska      1.29738    740339    738023    733391
# 2      4               Arizona     64.96246   7379346   7303398   7151502
# 3      5              Arkansas     58.42619   3040207   3030646   3011524
# 4      6            California    258.20877  40223504  39995077  39538223
# 5      8              Colorado     57.86332   5997070   5922618   5773714
# 6      9           Connecticut    746.69537   3615499   3612314   3605944
# 7     10              Delaware    522.08876   1017551   1008350    989948
# 8     11  District of Columbia  11735.91803    715891    707109    689545
# 9     12               Florida    416.95573  22359251  22085563  21538187
# 10    13               Georgia    191.59470  11019186  10916760  10711908
# 11    15                Hawaii    231.00763   1483762   1474265   1455271
# ...

# %%
data.dropna(inplace=True) # Le quito los NAN ya que sino no puedo juntar la columna del alcohol al dataframe anterior porque no coincidiría en elementos.

# %%
data
# Out:
#     fips           state   densityMi   pop2023   pop2022   pop2020   pop2019  \
# 0      1         Alabama   100.65438   5097641   5073187   5024279   4999822
# 1      2          Alaska     1.29738    740339    738023    733391    731075
# 2      4         Arizona    64.96246   7379346   7303398   7151502   7075549
# 3      5        Arkansas    58.42619   3040207   3030646   3011524   3001967
# 4      6      California   258.20877  40223504  39995077  39538223  39309799
# 5      8        Colorado    57.86332   5997070   5922618   5773714   5699264
# 6      9     Connecticut   746.69537   3615499   3612314   3605944   3602762
# 7     10        Delaware   522.08876   1017551   1008350    989948    980743
# 9     12         Florida   416.95573  22359251  22085563  21538187  21264502
# 10    13         Georgia   191.59470  11019186  10916760  10711908  10609487
# 11    15          Hawaii   231.00763   1483762   1474265   1455271   1445774
# ...

# %%
alcoholConsumptionGallons=data['alcoholConsumptionGallons'] #uno la tabla de alcohol del segundo datframe con la del primero

# %%
df['alcoholConsumptionGallons']=alcoholConsumptionGallons

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate  \
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
# Vamos a sacar ahora las conclusiones de la tabla

# %%
df['family_incomes(dollars)'] = df['family_incomes(dollars)'].astype(int) 

# Me estaba dando problemas la columna family incomes porque en la parte superior la estaba poniendo como string por lo que he decidido usar este metodo para convertirlo a inetger y así poder sacra media, .....

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  crime_rate  \
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
df=df.rename(columns={'Unnamed: 0': 'state'})

# %%
df
# Out:
#              state  Murder  Assault  UrbanPop  Rape  crime_rate  \
# 0          Alabama    13.2      236        58  21.2       453.6
# 1           Alaska    10.0      263        48  44.5       837.8
# 2          Arizona     8.1      294        80  31.0       654.8
# 3         Arkansas     8.8      190        50  19.5       671.9
# 4       California     9.0      276        91  40.6       442.0
# 5         Colorado     7.9      204        78  38.7       423.1
# 6      Connecticut     3.3      110        77  11.1       181.6
# 7         Delaware     5.9      238        72  15.8       431.9
# 8          Florida    15.4      335        80  31.9       383.6
# 9          Georgia    17.4      211        60  25.8       400.1
# 10          Hawaii     5.3       46        83  20.2       254.2
# 11           Idaho     2.6      120        54  14.2       242.6
# 12        Illinois    10.4      249        83  24.0       425.9
# 13         Indiana     7.2      113        65  21.0       357.7
# ...

# %%
df.corr()
# Out:
#                              Murder   Assault  UrbanPop      Rape  crime_rate  \
# Murder                     1.000000  0.801873  0.069573  0.563579    0.523129
# Assault                    0.801873  1.000000  0.258872  0.665241    0.561004
# UrbanPop                   0.069573  0.258872  1.000000  0.411341   -0.034546
# Rape                       0.563579  0.665241  0.411341  1.000000    0.576855
# crime_rate                 0.523129  0.561004 -0.034546  0.576855    1.000000
# family_incomes(dollars)   -0.492800 -0.223035  0.387034  0.041362   -0.388721
# alcoholConsumptionGallons  0.079544  0.146327  0.215194  0.047081   -0.123720
#
#                            family_incomes(dollars)  alcoholConsumptionGallons
# Murder                                   -0.492800                   0.079544
# Assault                                  -0.223035                   0.146327
# UrbanPop                                  0.387034                   0.215194
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std       min  \
# Murder                      50.0      7.788000      4.355510      0.80
# Assault                     50.0    170.760000     83.337661     45.00
# UrbanPop                    50.0     65.540000     14.474763     32.00
# Rape                        50.0     21.232000      9.366385      7.30
# crime_rate                  50.0    387.422000    158.952549    108.60
# family_incomes(dollars)     50.0  71156.100000  11623.266310  46637.00
# alcoholConsumptionGallons   49.0      2.465102      0.550947      1.35
#
#                                  25%       50%        75%       max
# Murder                         4.075      7.25     11.250     17.40
# Assault                      109.000    159.00    249.000    337.00
# UrbanPop                      54.500     66.00     77.750     91.00
# Rape                          15.075     20.10     26.175     46.00
# ...

# %%
df_subset = df[['alcoholConsumptionGallons', 'family_incomes(dollars)', 'Murder']]

# %%
corr_matrix = df_subset.corr()

# %%
corrs = corr_matrix.loc[['alcoholConsumptionGallons', 'family_incomes(dollars)', 'Murder'], ['alcoholConsumptionGallons', 'family_incomes(dollars)', 'Murder']]
print(corrs)
# Out:
#                            alcoholConsumptionGallons  family_incomes(dollars)  \
# alcoholConsumptionGallons                   1.000000                 0.285973
# family_incomes(dollars)                     0.285973                 1.000000
# Murder                                      0.079544                -0.492800
#
#                              Murder
# alcoholConsumptionGallons  0.079544
# family_incomes(dollars)   -0.492800
# Murder                     1.000000

# %%
# conclusion de las correlaciones entre lo arriba indicado es que que ni los asesinatos ni la renta de las familias influyen en el consumo de alcohol al tener una correcilacion cercana a 0. 
  En cambio los asesinatos tienen una correlación mas baja con la renta por lo que a más renta menos asesinatos(también tiene lógica).
# Out:
#   File "C:\Users\jelsa\AppData\Local\Temp\ipykernel_2228\2460687576.py", line 2
#     En cambio los asesinatos tienen una correlación mas baja con la renta por lo que a más renta menos asesinatos(también tiene lógica).
#     ^
# IndentationError: unexpected indent

# %%
df_subset = df[['family_incomes(dollars)', 'crime_rate', 'alcoholConsumptionGallons']]

# %%
corr_matrix = df_subset.corr()

# %%
corrs = corr_matrix.loc[['family_incomes(dollars)', 'crime_rate', 'alcoholConsumptionGallons'], ['family_incomes(dollars)', 'crime_rate', 'alcoholConsumptionGallons']]
print(corrs)
# Out:
#                            family_incomes(dollars)  crime_rate  \
# family_incomes(dollars)                   1.000000   -0.388721
# crime_rate                               -0.388721    1.000000
# alcoholConsumptionGallons                 0.285973   -0.123720
#
#                            alcoholConsumptionGallons
# family_incomes(dollars)                     0.285973
# crime_rate                                 -0.123720
# alcoholConsumptionGallons                   1.000000

# %%
# Conclusion la tasa de crimen no tiene tanta correlacion con la tasa de alcohol como se pensaba.

# %%
#%pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df[['family_incomes(dollars)']].hist(figsize=(15, 8));

# %%
for state in df['state']:
    df = df[df['state'] == state]
    alcoholConsumptionGallons_total = df['alcoholConsumptionGallons'].sum()
    Assault_total = df['Assault'].sum()
    relacion = alcoholConsumptionGallons_total / Assault_total
    print(f"El consumo de alcohol en {state} resultó en una relación de {relacion:.2f} asaltos.")
    
    # No parece que me haya salido.
# Out:
# El consumo de alcohol en Alabama resultó en una relación de 0.01 asaltos.
# El consumo de alcohol en Alaska resultó en una relación de nan asaltos.
# El consumo de alcohol en Arizona resultó en una relación de nan asaltos.
# El consumo de alcohol en Arkansas resultó en una relación de nan asaltos.
# El consumo de alcohol en California resultó en una relación de nan asaltos.
# El consumo de alcohol en Colorado resultó en una relación de nan asaltos.
# El consumo de alcohol en Connecticut resultó en una relación de nan asaltos.
# El consumo de alcohol en Delaware resultó en una relación de nan asaltos.
# El consumo de alcohol en Florida resultó en una relación de nan asaltos.
# El consumo de alcohol en Georgia resultó en una relación de nan asaltos.
# El consumo de alcohol en Hawaii resultó en una relación de nan asaltos.
# El consumo de alcohol en Idaho resultó en una relación de nan asaltos.
# El consumo de alcohol en Illinois resultó en una relación de nan asaltos.
# ...

# %%
df.to_csv('df.csv', index=False)

# %%
# %pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
with open('apis/password.txt', 'r') as file:
    
    passwd = file.read().split('\n')[0]

# %%
str_conn = f'mysql+pymysql://root:{passwd}@localhost:3306/blockbuster'
cursor = create_engine(str_conn)

# %%
df.to_sql(name=df,con=cursor, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14376\457545704.py in <module>
# ----> 1 df.to_sql(name=df,con=cursor, if_exists='replace', index=False)
#
# NameError: name 'df' is not defined
